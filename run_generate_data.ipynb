# %%
import generate_data
import objects_utils
import gl_graph

import graphlearning
from scipy import sparse
import numpy as np
import random

# %% [markdown]
# # MNIST Uniform kernel

# %%
# Load in VAE MNist data from graphlearning library
X,y = graphlearning.datasets.load("mnist", "vae")
label_arr = [4, 9]
n = 20

X, y, W = generate_data.GenerateWMat(X, y, n, label_arr)

# Save data
sparse.save_npz("data/X_mnist.npz", sparse.csr_matrix(X))
sparse.save_npz("data/W_mnist_uniform.npz", W)
np.save('data/y_mnist.npy', list(y))

evals_arr, evecs_arr = generate_data.GenEvecs(W)
np.save('data/ray_mnist_uniform.npy', evals_arr)
np.save('data/evecs_mnist_uniform.npy', evecs_arr)

# %%
evecs_arr = np.load('data/evecs_mnist_uniform.npy')
evals_arr = np.load('data/ray_mnist_uniform.npy')
y         = np.load('data/y_mnist.npy')

objects_utils.save_animation(
    evec_seq=evecs_arr,
    eigenvalue_seq=evals_arr,
    labels=y,
    title="MNIST Uniform",
    path="animation_mnist_uniform"   # writes animation.html + animation_data.js
)
# Out:
# Saved: animation_mnist_uniform.html  +  animation_mnist_uniform_data.js

# %% [markdown]
# # MNIST Uniform kernel

# %%
X, y, W = generate_data.GenerateWMat(X, y, n, label_arr, kernel="gaussian")

# Save data
sparse.save_npz("data/W_mnist_gaussian.npz", W)

evals_arr, evecs_arr = generate_data.GenEvecs(W)
np.save('data/ray_mnist_gaussian.npy', evals_arr)
np.save('data/evecs_mnist_gaussian.npy', evecs_arr)

# %%
evecs_arr = np.load('data/evecs_mnist_gaussian.npy')
evals_arr = np.load('data/ray_mnist_gaussian.npy')
y         = np.load('data/y_mnist.npy')

objects_utils.save_animation(
    evec_seq=evecs_arr,
    eigenvalue_seq=evals_arr,
    labels=y,
    title="MNIST Gaussian",
    path="animation_mnist_gaussian"   # writes animation.html + animation_data.js
)
# Out:
# Saved: animation_mnist_gaussian.html  +  animation_mnist_gaussian_data.js

# %% [markdown]
# # FashionMNIST Uniform kernel

# %%
# Load in VAE FashionMNist data from graphlearning library
X,y = graphlearning.datasets.load("fashionmnist", "vae")

# 5 Sandal
# 7 Sneaker
label_arr = [5, 7]
n = 30
X, y, W = generate_data.GenerateWMat(X, y, n, label_arr)

# Save data
sparse.save_npz("data/X_fashion.npz", sparse.csr_matrix(X))
sparse.save_npz("data/W_fashion_uniform.npz", W)
np.save('data/y_fashion.npy', list(y))

evals_arr, evecs_arr = generate_data.GenEvecs(W)
np.save('data/ray_fashion_uniform.npy', evals_arr)
np.save('data/evecs_fashion_uniform.npy', evecs_arr)

# %%
evecs_arr = np.load('data/evecs_fashion_uniform.npy')
evals_arr = np.load('data/ray_fashion_uniform.npy')
y         = np.load('data/y_fashion.npy')

objects_utils.save_animation(
    evec_seq=evecs_arr,
    eigenvalue_seq=evals_arr,
    labels=y,
    title="FashionMNIST Uniform",
    path="animation_fashion_uniform"   # writes animation.html + animation_data.js
)
# Out:
# Saved: animation_fashion_uniform.html  +  animation_fashion_uniform_data.js

# %% [markdown]
# # FashionMNIST Gaussian kernel

# %%
X, y, W = generate_data.GenerateWMat(X, y, n, label_arr, kernel="gaussian")

# Save data
sparse.save_npz("data/W_fashion_gaussian.npz", W)

evals_arr, evecs_arr = generate_data.GenEvecs(W)
np.save('data/ray_fashion_gaussian.npy', evals_arr)
np.save('data/evecs_fashion_gaussian.npy', evecs_arr)

# %%
evecs_arr = np.load('data/evecs_fashion_gaussian.npy')
evals_arr = np.load('data/ray_fashion_gaussian.npy')
y         = np.load('data/y_fashion.npy')

objects_utils.save_animation(
    evec_seq=evecs_arr,
    eigenvalue_seq=evals_arr,
    labels=y,
    title="FashionMNIST Gaussian",
    path="animation_fashion_gaussian"   # writes animation.html + animation_data.js
)
# Out:
# Saved: animation_fashion_gaussian.html  +  animation_fashion_gaussian_data.js

# %% [markdown]
# # Cifar10 Uniform kernel

# %%
# Load in simclr Cifar10 data from graphlearning library
X,y = graphlearning.datasets.load("cifar10", "simclr")

# 3 Cat
# 5 Dog
label_arr = [3, 5]
n = 30

X, y, W = generate_data.GenerateWMat(X, y, n, label_arr)

# Save data
sparse.save_npz("data/X_cifar.npz", sparse.csr_matrix(X))
sparse.save_npz("data/W_cifar_uniform.npz", W)
np.save('data/y_cifar.npy', list(y))

evals_arr, evecs_arr = generate_data.GenEvecs(W)
np.save('data/ray_cifar_uniform.npy', evals_arr)
np.save('data/evecs_cifar_uniform.npy', evecs_arr)

# %%
evecs_arr = np.load('data/evecs_cifar_uniform.npy')
evals_arr = np.load('data/ray_cifar_uniform.npy')
y         = np.load('data/y_cifar.npy')

objects_utils.save_animation(
    evec_seq=evecs_arr,
    eigenvalue_seq=evals_arr,
    labels=y,
    title="Cifar Uniform",
    path="animation_cifar_uniform"   # writes animation.html + animation_data.js
)
# Out:
# Saved: animation_cifar_uniform.html  +  animation_cifar_uniform_data.js

# %% [markdown]
# # Cifar10 Gaussian kernel

# %%
X, y, W = generate_data.GenerateWMat(X, y, n, label_arr, kernel="gaussian")

# Save data
sparse.save_npz("data/W_cifar_gaussian.npz", W)

evals_arr, evecs_arr = generate_data.GenEvecs(W)
np.save('data/ray_cifar_gaussian.npy', evals_arr)
np.save('data/evecs_cifar_gaussian.npy', evecs_arr)

# %%
evecs_arr = np.load('data/evecs_cifar_gaussian.npy')
evals_arr = np.load('data/ray_cifar_gaussian.npy')
y         = np.load('data/y_cifar.npy')

objects_utils.save_animation(
    evec_seq=evecs_arr,
    eigenvalue_seq=evals_arr,
    labels=y,
    title="Cifar Gaussian",
    path="animation_cifar_gaussian"   # writes animation.html + animation_data.js
)
